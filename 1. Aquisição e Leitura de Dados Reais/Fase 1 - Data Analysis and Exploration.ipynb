# %% [markdown]
# # 1. Analisando Dados de Produção Hospitalar

# %%
import pandas as pd

# %% [markdown]
# # Importando os Dados

# %%
dados_hospitalares_1 = pd.read_csv(r"E:\PÓS GRADUAÇÃO\Fase 1 - Data Analysis and Exploration\2. Análise exploratória de dados\1. Aquisição e Leitura de Dados Reais\sih_cnv_qiuf135059177_102_198_52.csv", sep = ";", encoding="ISO-8859-1", skiprows = 3, skipfooter = 12, engine='python', thousands = ".", decimal = ".")

# %% [markdown]
# # DataFrame

# %%
dados_hospitalares_1
# Out:
#       Unidade da Federação     2008/Jan      2008/Fev      2008/Mar  \
# 0              11 Rondônia   1388528,39    2931283,42    1541682,52
# 1                  12 Acre    902416,00    1497206,26    1794028,48
# 2              13 Amazonas   4735529,42    7118990,57    8196635,49
# 3               14 Roraima    657889,53     777939,31     718688,03
# 4                  15 Pará  18864744,11   19553758,20   21937342,70
# 5                 16 Amapá   1120973,34    1268740,33     974651,24
# 6             17 Tocantins   3441592,69    4985688,85    6205612,60
# 7              21 Maranhão  10723506,39   13559679,41   13985142,36
# 8                 22 Piauí   7985142,43   10079928,25   10298372,45
# 9                 23 Ceará  15539821,90   25735101,55   28724625,75
# 10  24 Rio Grande do Norte   5947814,08    9509755,83   10352238,59
# 11              25 Paraíba  10723002,45   11386274,47   12053643,87
# 12           26 Pernambuco  14393949,89   24181400,95   29991302,71
# ...

# %% [markdown]
# # Função Head dentro do DataFrame

# %% [markdown]
# ## A função Head mostra as 5 primeiras linhas de uma tabela

# %%
dados_hospitalares_1.head()
# Out:
#   Unidade da Federação     2008/Jan     2008/Fev     2008/Mar     2008/Abr  \
# 0          11 Rondônia   1388528,39   2931283,42   1541682,52   1525314,96
# 1              12 Acre    902416,00   1497206,26   1794028,48   1730469,42
# 2          13 Amazonas   4735529,42   7118990,57   8196635,49   8259378,42
# 3           14 Roraima    657889,53    777939,31    718688,03    839994,39
# 4              15 Pará  18864744,11  19553758,20  21937342,70  20842829,69
#
#       2008/Mai     2008/Jun     2008/Jul     2008/Ago     2008/Set  ...  \
# 0   1645953,84   1406150,68   3065279,01   3231494,61   3117178,63  ...
# 1   1819443,92   1828496,00   2511754,59   2089107,14   2275708,53  ...
# 2   7831399,90   8477273,62   9368858,72   9352532,70   9363099,35  ...
# 3    862347,96    832440,66    996693,09    894271,18    910424,17  ...
# 4  23249952,88  23240687,56  24002223,56  23341218,03  25172261,32  ...
#
#       2024/Mai     2024/Jun     2024/Jul     2024/Ago     2024/Set  \
# ...

# %% [markdown]
# # Função Tail dentro do DataFrame

# %% [markdown]
# ## A função Tail mostra as 5 últimas linhas de uma tabela

# %%
dados_hospitalares_1.tail()
# Out:
#      Unidade da Federação     2008/Jan     2008/Fev     2008/Mar     2008/Abr  \
# 22   43 Rio Grande do Sul  30931325,46  57363420,01  51547794,07  56673338,49
# 23  50 Mato Grosso do Sul   5377392,11   7002472,61   8423933,19   8797487,68
# 24         51 Mato Grosso   4795299,01   8684882,23   7886243,14   8794109,79
# 25               52 Goiás  15310637,29  22258668,68  21442515,75  20921212,45
# 26    53 Distrito Federal   4745919,19   7632480,67   9647203,26  11098732,99
#
#        2008/Mai     2008/Jun     2008/Jul     2008/Ago     2008/Set  ...  \
# 22  48397733,07  52413429,62  56636376,98  56113054,70  55356224,30  ...
# 23   9770421,80  10905392,18  10249299,82   9671553,45  10218511,05  ...
# 24   9231645,40  10221763,77   9163314,28   9243148,81   9052354,89  ...
# 25  21615970,67  18270043,87  20540517,13  20650730,67  20868443,56  ...
# 26  12891719,72  12850125,67  12565646,74  13710857,89  13165106,20  ...
#
# ...

# %% [markdown]
# # Informações da tabela

# %%
dados_hospitalares_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27 entries, 0 to 26
# Columns: 207 entries, Unidade da Federação to Total
# dtypes: object(207)
# memory usage: 43.8+ KB

# %%
pd.options.display.float_format = "{:.2f}".format

# %% [markdown]
# # Desafio da aula 1: Visualizar a coluna mais recente que tiver

# %% [markdown]
# ## Primeira forma

# %%
dados_hospitalares_1.iloc[-2]
# Out:
# Unidade da Federação         52 Goiás
# 2008/Jan                  15310637,29
# 2008/Fev                  22258668,68
# 2008/Mar                  21442515,75
# 2008/Abr                  20921212,45
#                             ...
# 2024/Out                  52852765,25
# 2024/Nov                  51788573,74
# 2024/Dez                  53678493,77
# 2025/Jan                  55038161,04
# Total                   7343471947,19
# Name: 25, Length: 207, dtype: object

# %% [markdown]
# ## Segunda forma

# %%
dados_hospitalares_1["2008/Jan"]
# Out:
# 0      1388528,39
# 1       902416,00
# 2      4735529,42
# 3       657889,53
# 4     18864744,11
# 5      1120973,34
# 6      3441592,69
# 7     10723506,39
# 8      7985142,43
# 9     15539821,90
# 10     5947814,08
# 11    10723002,45
# 12    14393949,89
# 13     6243726,32
# 14     2780750,11
# 15    21211522,47
# 16    45671659,76
# 17     5456723,98
# 18    23025258,52
# 19    91678473,48
# 20    38266347,46
# 21    16504913,45
# 22    30931325,46
# 23     5377392,11
# 24     4795299,01
# 25    15310637,29
# 26     4745919,19
# Name: 2008/Jan, dtype: object

# %% [markdown]
# ## Terceira forma

# %%
from datetime import datetime
import locale

# Configura o locale para português (Brasil)
locale.setlocale(locale.LC_TIME, 'pt_BR.UTF-8')

# Definindo os parâmetros para sempre pegar o ano e o mês atual
ano = datetime.now().year 
mes = datetime.now().strftime("%b")

parametro = (f"{ano}/{mes}")
print(parametro)

# Tratativa para caso aconteça de não ter dados para aquele período
dados = dados_hospitalares_1.get(parametro, "Não há dados para essa referência")

print(dados)
# Out:
# 2025/abr
# Não há dados para essa referência

# %% [markdown]
# # 2. Visualização de Dados

# %% [markdown]
# ## Introdução ao pyplot
# matplotlib.pyplot é uma coleção de funções que fazem o matplotlib funcionar como o MATLAB. Cada função pyplot faz alguma alteração em uma figura: por exemplo, cria uma figura, cria uma área de plotagem em uma figura, plota algumas linhas em uma área de plotagem, decora o gráfico com rótulos, etc.

# %%
import matplotlib.pyplot as plt

plt.plot([1, 3, 2, 3, 1, 3, 2, 3])
plt.ylabel('Escala Numérica')
plt.show()

# %% [markdown]
# ## Visualização das Informações Hospitalares

# %%
import matplotlib.pyplot as plt
import pandas as pd

# 1. Limpeza da coluna '2008/Jan' (remover texto ou valores não numéricos)
dados_hospitalares_1['2025/Jan'] = dados_hospitalares_1['2025/Jan'].replace(r'[^\d.-]', '', regex=True)

# 2. Converter a coluna para numérico, forçando qualquer valor inválido a se tornar NaN
dados_hospitalares_1['2025/Jan'] = pd.to_numeric(dados_hospitalares_1['2025/Jan'], errors='coerce')

# 3. Tratar valores 'NaN' (se necessário)
dados_hospitalares_1['2025/Jan'] = dados_hospitalares_1['2025/Jan'].fillna(0)

# 4. Verifique se os dados estão corretos
print(dados_hospitalares_1[['Unidade da Federação', '2025/Jan']].head())  # Verifique se os dados foram corrigidos

# 5. Plotar o gráfico
plt.figure(figsize=(12, 8))  # Aumenta o tamanho do gráfico para acomodar melhor as etiquetas

# Criar gráfico de barras
dados_hospitalares_1.plot(x='Unidade da Federação', y='2025/Jan', kind='bar', color='blue')

# Personalizar o gráfico
plt.title("Valores de 2025/Jan por Unidade da Federação")
plt.xlabel("Unidade da Federação")
plt.ylabel("Valores de 2025/Jan")

# Exibir o gráfico
plt.show()
# Out:
#   Unidade da Federação      2025/Jan
# 0          11 Rondônia 1174142822.00
# 1              12 Acre          0.00
# 2          13 Amazonas 2292435330.00
# 3           14 Roraima          0.00
# 4              15 Pará 4831258666.00
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[65], line 28
#      25 plt.ylabel("Valores de 2025/Jan")
#      27 # Exibir o gráfico
# ---> 28 plt.show()
#
# File D:\Lib\site-packages\matplotlib\pyplot.py:614, in show(*args, **kwargs)
#     570 """
#     571 Display all open figures.
#     572
#    (...)
#     611 explicitly there.
#     612 """
#     613 _warn_if_gui_out_of_main_thread()
# --> 614 return _get_backend_mod().show(*args, **kwargs)
#
# File D:\Lib\site-packages\matplotlib_inline\backend_inline.py:90, in show(close, block)
#      88 try:
#      89     for figure_manager in Gcf.get_all_fig_managers():
# ...

# %% [markdown]
# ## Desafio 2: Executar o gráfico com o mês recente

# %%
import matplotlib.pyplot as plt
import pandas as pd

# 1. Limpeza da coluna '2008/Jan' (remover texto ou valores não numéricos)
dados_hospitalares_1['2008/Jan'] = dados_hospitalares_1['2008/Jan'].replace(r'[^\d.-]', '', regex=True)

# 2. Converter a coluna para numérico, forçando qualquer valor inválido a se tornar NaN
dados_hospitalares_1['2008/Jan'] = pd.to_numeric(dados_hospitalares_1['2008/Jan'], errors='coerce')

# 3. Tratar valores 'NaN' (se necessário)
dados_hospitalares_1['2008/Jan'] = dados_hospitalares_1['2008/Jan'].fillna(0)

# 4. Verifique se os dados estão corretos
print(dados_hospitalares_1[['Unidade da Federação', '2008/Jan']].head())  # Verifique se os dados foram corrigidos

# 5. Plotar o gráfico
plt.figure(figsize=(12, 8))  # Aumenta o tamanho do gráfico para acomodar melhor as etiquetas

# Criar gráfico de barras
dados_hospitalares_1.plot(x='Unidade da Federação', y='2008/Jan', kind='bar', color='blue')

# Personalizar o gráfico
plt.title("Valores de 2008/Jan por Unidade da Federação")
plt.xlabel("Unidade da Federação")
plt.ylabel("Valores de 2008/Jan")

# Exibir o gráfico
plt.show()
# Out:
#   Unidade da Federação    2008/Jan
# 0          11 Rondônia   138852839
# 1              12 Acre    90241600
# 2          13 Amazonas   473552942
# 3           14 Roraima    65788953
# 4              15 Pará  1886474411

# %% [markdown]
# ## Desafio 3: Deixar as legendas ânguladas (0, 45 etc) para facilitar a leitura

# %%
import matplotlib.pyplot as plt
import pandas as pd

# 1. Limpeza da coluna '2008/Jan' (remover texto ou valores não numéricos)
# Remover qualquer coisa que não seja número ou ponto (como caracteres especiais ou espaços extras)
dados_hospitalares_1['2008/Jan'] = dados_hospitalares_1['2008/Jan'].replace(r'[^\d.-]', '', regex=True)

# 2. Converter a coluna para numérico, forçando qualquer valor inválido a se tornar NaN
dados_hospitalares_1['2008/Jan'] = pd.to_numeric(dados_hospitalares_1['2008/Jan'], errors='coerce')

# 3. Tratar valores 'NaN' (se necessário)
# Aqui você pode substituir por 0, pela média ou pela mediana
dados_hospitalares_1['2008/Jan'] = dados_hospitalares_1['2008/Jan'].fillna(0)

# 4. Verifique se os dados estão corretos
print(dados_hospitalares_1[['Unidade da Federação', '2008/Jan']].head())  # Verifique se os dados foram corrigidos

# 5. Plotar o gráfico
plt.figure(figsize=(12, 8))  # Aumenta o tamanho do gráfico para acomodar melhor as etiquetas

# Criar gráfico de barras
dados_hospitalares_1.plot(x='Unidade da Federação', y='2008/Jan', kind='bar', color='blue')

# Personalizar o gráfico
plt.title("Valores de 2008/Jan por Unidade da Federação")
plt.xlabel("Unidade da Federação")
plt.ylabel("Valores de 2008/Jan")

# Ajustar o ângulo das etiquetas para 45 graus e garantir o espaço
plt.xticks(rotation=45, ha='right')  # 'ha' para alinhar corretamente as etiquetas
plt.tight_layout()  # Ajuste automático para evitar sobreposição

# Exibir o gráfico
plt.show()
# Out:
#   Unidade da Federação    2008/Jan
# 0          11 Rondônia   138852839
# 1              12 Acre    90241600
# 2          13 Amazonas   473552942
# 3           14 Roraima    65788953
# 4              15 Pará  1886474411

# %% [markdown]
# # 3. Manipulação de Dados

# %%
# Carregar os dados
dados_hospitalares_1 = pd.read_csv(r"E:\PÓS GRADUAÇÃO\Fase 1 - Data Analysis and Exploration\2. Análise exploratória de dados\1. Aquisição e Leitura de Dados Reais\sih_cnv_qiuf135059177_102_198_52.csv", sep=";", encoding="ISO-8859-1", skiprows=3, skipfooter=12, engine='python', decimal=",", thousands=".")

# %%
dados_hospitalares_1.head()
# Out:
#   Unidade da Federação     2008/Jan     2008/Fev     2008/Mar     2008/Abr  \
# 0          11 Rondônia   1388528.39   2931283.42   1541682.52   1525314.96
# 1              12 Acre    902416.00   1497206.26   1794028.48   1730469.42
# 2          13 Amazonas   4735529.42   7118990.57   8196635.49   8259378.42
# 3           14 Roraima    657889.53    777939.31    718688.03    839994.39
# 4              15 Pará  18864744.11  19553758.20  21937342.70  20842829.69
#
#       2008/Mai     2008/Jun     2008/Jul     2008/Ago     2008/Set  ...  \
# 0   1645953.84   1406150.68   3065279.01   3231494.61   3117178.63  ...
# 1   1819443.92   1828496.00   2511754.59   2089107.14   2275708.53  ...
# 2   7831399.90   8477273.62   9368858.72   9352532.70   9363099.35  ...
# 3    862347.96    832440.66    996693.09    894271.18    910424.17  ...
# 4  23249952.88  23240687.56  24002223.56  23341218.03  25172261.32  ...
#
#       2024/Mai     2024/Jun     2024/Jul     2024/Ago     2024/Set  \
# ...

# %%
dados_hospitalares_1[["2008/Ago", "2008/Set"]].head()
# Out:
#       2008/Ago     2008/Set
# 0   3231494,61   3117178,63
# 1   2089107,14   2275708,53
# 2   9352532,70   9363099,35
# 3    894271,18    910424,17
# 4  23341218,03  25172261,32

# %% [markdown]
# ## Limpar dados vazios com a média

# %%
# Armazenar a coluna de "Unidade da Federação" antes de fazer alterações
unidade_federacao = dados_hospitalares_1["Unidade da Federação"]

# Remover a coluna de "Unidade da Federação" temporariamente para ajustar as colunas numéricas
dados_hospitalares_1 = dados_hospitalares_1.drop(columns=["Unidade da Federação"])

# Converter as colunas restantes para numérico, forçando erro para 'coerce' (transformando não numéricos em NaN)
dados_hospitalares_1 = dados_hospitalares_1.apply(pd.to_numeric, errors='coerce')

# Adicionar a coluna de "Unidade da Federação" de volta
dados_hospitalares_1["Unidade da Federação"] = unidade_federacao

# Verificar os dados ajustados
print(dados_hospitalares_1.head())

# Calcular a média das colunas numéricas
media_dados = dados_hospitalares_1.mean(numeric_only=True)

# Exibir a média
print(media_dados)
# Out:
#       2008/Jan     2008/Fev     2008/Mar     2008/Abr     2008/Mai  \
# 0   1388528.39   2931283.42   1541682.52   1525314.96   1645953.84
# 1    902416.00   1497206.26   1794028.48   1730469.42   1819443.92
# 2   4735529.42   7118990.57   8196635.49   8259378.42   7831399.90
# 3    657889.53    777939.31    718688.03    839994.39    862347.96
# 4  18864744.11  19553758.20  21937342.70  20842829.69  23249952.88
#
#       2008/Jun     2008/Jul     2008/Ago     2008/Set     2008/Out  ...  \
# 0   1406150.68   3065279.01   3231494.61   3117178.63   3068430.44  ...
# 1   1828496.00   2511754.59   2089107.14   2275708.53   1923886.57  ...
# 2   8477273.62   9368858.72   9352532.70   9363099.35   8618318.83  ...
# 3    832440.66    996693.09    894271.18    910424.17   1191770.32  ...
# 4  23240687.56  24002223.56  23341218.03  25172261.32  24011712.48  ...
#
#       2024/Jun     2024/Jul     2024/Ago     2024/Set     2024/Out  \
# ...

# %%
colunas_usaveis = media_dados.index.tolist()
colunas_usaveis.insert(0, "Unidade da Federação")
colunas_usaveis
# Out:
# ['Unidade da Federação',
#  '2008/Jan',
#  '2008/Fev',
#  '2008/Mar',
#  '2008/Abr',
#  '2008/Mai',
#  '2008/Jun',
#  '2008/Jul',
#  '2008/Ago',
#  '2008/Set',
#  '2008/Out',
#  '2008/Nov',
#  '2008/Dez',
#  '2009/Jan',
#  '2009/Fev',
#  '2009/Mar',
#  '2009/Abr',
#  '2009/Mai',
#  '2009/Jun',
#  '2009/Jul',
#  '2009/Ago',
#  '2009/Set',
#  '2009/Out',
#  '2009/Nov',
#  '2009/Dez',
#  '2010/Jan',
#  '2010/Fev',
#  '2010/Mar',
#  '2010/Abr',
#  '2010/Mai',
#  '2010/Jun',
#  '2010/Jul',
#  '2010/Ago',
#  '2010/Set',
#  '2010/Out',
#  '2010/Nov',
#  '2010/Dez',
#  '2011/Jan',
#  '2011/Fev',
#  '2011/Mar',
#  '2011/Abr',
#  '2011/Mai',
#  '2011/Jun',
#  '2011/Jul',
#  '2011/Ago',
#  '2011/Set',
#  '2011/Out',
#  '2011/Nov',
#  '2011/Dez',
#  '2012/Jan',
#  '2012/Fev',
#  '2012/Mar',
#  '2012/Abr',
#  '2012/Mai',
#  '2012/Jun',
#  '2012/Jul',
#  '2012/Ago',
#  '2012/Set',
#  '2012/Out',
#  '2012/Nov',
#  '2012/Dez',
#  '2013/Jan',
#  '2013/Fev',
#  '2013/Mar',
#  '2013/Abr',
# ...

# %%
dados_usaveis = dados_hospitalares_1[colunas_usaveis]
dados_usaveis.head()
# Out:
#   Unidade da Federação     2008/Jan     2008/Fev     2008/Mar     2008/Abr  \
# 0          11 Rondônia   1388528.39   2931283.42   1541682.52   1525314.96
# 1              12 Acre    902416.00   1497206.26   1794028.48   1730469.42
# 2          13 Amazonas   4735529.42   7118990.57   8196635.49   8259378.42
# 3           14 Roraima    657889.53    777939.31    718688.03    839994.39
# 4              15 Pará  18864744.11  19553758.20  21937342.70  20842829.69
#
#       2008/Mai     2008/Jun     2008/Jul     2008/Ago     2008/Set  ...  \
# 0   1645953.84   1406150.68   3065279.01   3231494.61   3117178.63  ...
# 1   1819443.92   1828496.00   2511754.59   2089107.14   2275708.53  ...
# 2   7831399.90   8477273.62   9368858.72   9352532.70   9363099.35  ...
# 3    862347.96    832440.66    996693.09    894271.18    910424.17  ...
# 4  23249952.88  23240687.56  24002223.56  23341218.03  25172261.32  ...
#
#       2024/Mai     2024/Jun     2024/Jul     2024/Ago     2024/Set  \
# ...

# %%
dados_usaveis = dados_usaveis.set_index("Unidade da Federação")
dados_usaveis.head()
# Out:
#                          2008/Jan     2008/Fev     2008/Mar     2008/Abr  \
# Unidade da Federação
# 11 Rondônia            1388528.39   2931283.42   1541682.52   1525314.96
# 12 Acre                 902416.00   1497206.26   1794028.48   1730469.42
# 13 Amazonas            4735529.42   7118990.57   8196635.49   8259378.42
# 14 Roraima              657889.53    777939.31    718688.03    839994.39
# 15 Pará               18864744.11  19553758.20  21937342.70  20842829.69
#
#                          2008/Mai     2008/Jun     2008/Jul     2008/Ago  \
# Unidade da Federação
# 11 Rondônia            1645953.84   1406150.68   3065279.01   3231494.61
# 12 Acre                1819443.92   1828496.00   2511754.59   2089107.14
# 13 Amazonas            7831399.90   8477273.62   9368858.72   9352532.70
# 14 Roraima              862347.96    832440.66    996693.09    894271.18
# 15 Pará               23249952.88  23240687.56  24002223.56  23341218.03
#
# ...

# %%
dados_usaveis["2008/Jan"].head()
# Out:
# Unidade da Federação
# 11 Rondônia     1388528.39
# 12 Acre          902416.00
# 13 Amazonas     4735529.42
# 14 Roraima       657889.53
# 15 Pará        18864744.11
# Name: 2008/Jan, dtype: float64

# %%
dados_usaveis.loc["12 Acre"]
# Out:
# 2008/Jan    9.024160e+05
# 2008/Fev    1.497206e+06
# 2008/Mar    1.794028e+06
# 2008/Abr    1.730469e+06
# 2008/Mai    1.819444e+06
#                 ...
# 2024/Out    5.425939e+06
# 2024/Nov    5.449709e+06
# 2024/Dez    4.235483e+06
# 2025/Jan             NaN
# Total       6.466201e+08
# Name: 12 Acre, Length: 206, dtype: float64

# %%
dados_usaveis.iloc[1]
# Out:
# 2008/Jan    9.024160e+05
# 2008/Fev    1.497206e+06
# 2008/Mar    1.794028e+06
# 2008/Abr    1.730469e+06
# 2008/Mai    1.819444e+06
#                 ...
# 2024/Out    5.425939e+06
# 2024/Nov    5.449709e+06
# 2024/Dez    4.235483e+06
# 2025/Jan             NaN
# Total       6.466201e+08
# Name: 12 Acre, Length: 206, dtype: float64

# %%
dados_usaveis.plot(figsize=(12,6))
# Out:
# <Axes: xlabel='Unidade da Federação'>

# %%
dados_usaveis.T.head()
# Out:
# Unidade da Federação  11 Rondônia     12 Acre  13 Amazonas  14 Roraima  \
# 2008/Jan               1388528.39   902416.00   4735529.42   657889.53
# 2008/Fev               2931283.42  1497206.26   7118990.57   777939.31
# 2008/Mar               1541682.52  1794028.48   8196635.49   718688.03
# 2008/Abr               1525314.96  1730469.42   8259378.42   839994.39
# 2008/Mai               1645953.84  1819443.92   7831399.90   862347.96
#
# Unidade da Federação      15 Pará    16 Amapá  17 Tocantins  21 Maranhão  \
# 2008/Jan              18864744.11  1120973.34    3441592.69  10723506.39
# 2008/Fev              19553758.20  1268740.33    4985688.85  13559679.41
# 2008/Mar              21937342.70   974651.24    6205612.60  13985142.36
# 2008/Abr              20842829.69  1141137.32    4984482.09  14809416.46
# 2008/Mai              23249952.88   866346.18    5511002.46  14505727.38
#
# Unidade da Federação     22 Piauí     23 Ceará  ...  32 Espírito Santo  \
# ...

# %%
dados_usaveis.T.plot(figsize=(12,6))
# Out:
# <Axes: >

# %%
dados_usaveis.T.tail()
# Out:
# Unidade da Federação   11 Rondônia       12 Acre   13 Amazonas    14 Roraima  \
# 2024/Out              1.456303e+07  5.425939e+06  2.351123e+07  3.605912e+06
# 2024/Nov              1.584881e+07  5.449709e+06  2.235813e+07  3.914959e+06
# 2024/Dez              1.158733e+07  4.235483e+06  1.858039e+07  2.444787e+06
# 2025/Jan              1.174143e+07           NaN  2.292435e+07           NaN
# Total                 1.560285e+09  6.466201e+08  2.888132e+09  4.899701e+08
#
# Unidade da Federação       15 Pará      16 Amapá  17 Tocantins   21 Maranhão  \
# 2024/Out              5.830041e+07  4.459227e+06  1.003669e+07  4.605589e+07
# 2024/Nov              5.708936e+07  4.582967e+06  9.291853e+06  4.335191e+07
# 2024/Dez              5.752713e+07  3.528949e+06  9.231870e+06  3.963093e+07
# 2025/Jan              4.831259e+07  3.830730e+06  1.009889e+07  4.077071e+07
# Total                 6.983761e+09  4.836616e+08  1.492979e+09  5.779843e+09
#
# ...

# %%
dados_usaveis = dados_usaveis.drop("Total", axis=1)
dados_usaveis.head()
# Out:
#                          2008/Jan     2008/Fev     2008/Mar     2008/Abr  \
# Unidade da Federação
# 11 Rondônia            1388528.39   2931283.42   1541682.52   1525314.96
# 12 Acre                 902416.00   1497206.26   1794028.48   1730469.42
# 13 Amazonas            4735529.42   7118990.57   8196635.49   8259378.42
# 14 Roraima              657889.53    777939.31    718688.03    839994.39
# 15 Pará               18864744.11  19553758.20  21937342.70  20842829.69
#
#                          2008/Mai     2008/Jun     2008/Jul     2008/Ago  \
# Unidade da Federação
# 11 Rondônia            1645953.84   1406150.68   3065279.01   3231494.61
# 12 Acre                1819443.92   1828496.00   2511754.59   2089107.14
# 13 Amazonas            7831399.90   8477273.62   9368858.72   9352532.70
# 14 Roraima              862347.96    832440.66    996693.09    894271.18
# 15 Pará               23249952.88  23240687.56  24002223.56  23341218.03
#
# ...

# %%
dados_usaveis.T.plot(figsize=(12,6))
# Out:
# <Axes: >

# %% [markdown]
# ## Desafio 1: Ajustar Legenda

# %%
import matplotlib.pyplot as plt

dados_usaveis.T.plot(figsize=(18,9)) 

plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.15), ncol=9, fontsize=8, title="Federação", title_fontsize=12, labelspacing=1.5, handletextpad=1)

# Personalizando os ticks
plt.xticks(rotation=45, fontsize=10)
plt.yticks(fontsize=10)

# Ativando o grid
plt.grid(True, linestyle='--', color='gray', alpha=0.7)

# Exibindo o gráfico
plt.show()

# %% [markdown]
# ## Desafio 2: Retocar os Títulos

# %%
import matplotlib.pyplot as plt

dados_usaveis.T.plot(figsize=(18,9)) 

plt.style.use('dark_background')
plt.title('Volume por Federação', fontsize=16, color='white')
plt.ylabel('Volumetria', fontsize=12, color='white')

plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.15), ncol=9, fontsize=8, title="Federação", title_fontsize=12, labelspacing=1.5, handletextpad=1)

# Personalizando os ticks
plt.xticks(rotation=45, fontsize=10)
plt.yticks(fontsize=10)

# Ativando o grid
plt.grid(True, linestyle='--', color='gray', alpha=0.7)

# Exibindo o gráfico
plt.show()

# %% [markdown]
# ## Ajustando o Gráfico para pegar amostras aleatórias

# %%
dados_usaveis.sample(n = 5)
# Out:
#                            2008/Jan     2008/Fev     2008/Mar     2008/Abr  \
# Unidade da Federação
# 14 Roraima                657889.53    777939.31    718688.03    839994.39
# 24 Rio Grande do Norte   5947814.08   9509755.83  10352238.59  10855108.50
# 15 Pará                 18864744.11  19553758.20  21937342.70  20842829.69
# 51 Mato Grosso           4795299.01   8684882.23   7886243.14   8794109.79
# 28 Sergipe               2780750.11   3676483.16   5051473.61   5046063.36
#
#                            2008/Mai     2008/Jun     2008/Jul     2008/Ago  \
# Unidade da Federação
# 14 Roraima                862347.96    832440.66    996693.09    894271.18
# 24 Rio Grande do Norte  11160168.19  10475071.38  11386349.96  10640817.47
# 15 Pará                 23249952.88  23240687.56  24002223.56  23341218.03
# 51 Mato Grosso           9231645.40  10221763.77   9163314.28   9243148.81
# 28 Sergipe               4741151.56   5401259.63   5521904.44   5238398.50
#
# ...

# %%
dados_usaveis.sample(n = 5).T.plot(figsize=(18,9)) 

plt.style.use('dark_background')
plt.title('Volume por Federação', fontsize=16, color='white')
plt.ylabel('Volumetria', fontsize=12, color='white')

plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.15), ncol=9, fontsize=8, title="Federação", title_fontsize=12, labelspacing=1.5, handletextpad=1)

# Personalizando os ticks
plt.xticks(rotation=45, fontsize=10)
plt.yticks(fontsize=10)

# Ativando o grid
plt.grid(True, linestyle='--', color='gray', alpha=0.7)

# Exibindo o gráfico
plt.show()

# %%
dados_usaveis.sort_values("2008/Fev").head()
# Out:
#                         2008/Jan    2008/Fev    2008/Mar    2008/Abr  \
# Unidade da Federação
# 14 Roraima             657889.53   777939.31   718688.03   839994.39
# 16 Amapá              1120973.34  1268740.33   974651.24  1141137.32
# 12 Acre                902416.00  1497206.26  1794028.48  1730469.42
# 11 Rondônia           1388528.39  2931283.42  1541682.52  1525314.96
# 28 Sergipe            2780750.11  3676483.16  5051473.61  5046063.36
#
#                         2008/Mai    2008/Jun    2008/Jul    2008/Ago  \
# Unidade da Federação
# 14 Roraima             862347.96   832440.66   996693.09   894271.18
# 16 Amapá               866346.18  1440978.95  1426659.48  1475551.38
# 12 Acre               1819443.92  1828496.00  2511754.59  2089107.14
# 11 Rondônia           1645953.84  1406150.68  3065279.01  3231494.61
# 28 Sergipe            4741151.56  5401259.63  5521904.44  5238398.50
#
#                         2008/Set    2008/Out  ...     2024/Abr     2024/Mai  \
# ...

# %% [markdown]
# ## Ajustando o valor de Y (le8)

# %%
dados_hospitalares_1["2008/Ago"].mean()
# Out:
# np.float64(27800320.306666665)

# %%
import matplotlib.ticker as ticker

axis = dados_hospitalares_1.plot(x = "Unidade da Federação", y = "2008/Fev", kind = "line", figsize=(9,6))
axis.yaxis.set_major_formatter(ticker.StrMethodFormatter("{x:,.2f}"))

plt.show()

# %% [markdown]
# # Tipos de Plot

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.ticker as tck

# %% [markdown]
# ## Line

# %%
info = {'Fruta': ['Melancia', 'Pêra', 'Banana', 'Morango'],
        'Quantidade': [5, 8, 3, 9]}

info = pd.DataFrame(info)

info.plot(x = "Fruta", y = "Quantidade", kind = "line" ,figsize = (9,6))

plt.show()

# %% [markdown]
# ## Bar

# %%
info = {'Fruta': ['Melancia', 'Pêra', 'Banana', 'Morango'],
        'Quantidade': [5, 8, 3, 9]}

info = pd.DataFrame(info)

info.plot(x = "Fruta", y = "Quantidade", kind = "bar" ,figsize = (9,6))

plt.show()

# %% [markdown]
# ## Histograma

# %%
info = {'Fruta': ['Melancia', 'Pêra', 'Banana', 'Morango'],
        'Quantidade': [5, 8, 3, 9]}

info = pd.DataFrame(info)

info.plot(x = "Fruta", y = "Quantidade", kind = "hist" ,figsize = (9,6))

plt.show()

# %% [markdown]
# ## Pizza

# %%
info = {'Fruta': ['Melancia', 'Pêra', 'Banana', 'Morango'],
        'Quantidade': [5, 8, 3, 9]}

info = pd.DataFrame(info)

info.plot(x = "Fruta", y = "Quantidade", kind = "pie" ,figsize = (9,6))

plt.show()

# %% [markdown]
# ## Escala

# %%
info = {'Fruta': ['Melancia', 'Pêra', 'Banana', 'Morango'],
        'Quantidade': [5, 8, 3, 9]}

info = pd.DataFrame(info)

info.plot(x = "Fruta", y = "Quantidade", kind = "scatter" ,figsize = (9,6))

plt.show()

# %% [markdown]
# # 5. Manipulação e Interpretação de Gráficos

# %%
import pandas as pd

# Carregar os dados
dados_hospitalares_1 = pd.read_csv(r"E:\PÓS GRADUAÇÃO\Fase 1 - Data Analysis and Exploration\2. Análise exploratória de dados\1. Aquisição e Leitura de Dados Reais\sih_cnv_qiuf135059177_102_198_52.csv", sep=";", encoding="ISO-8859-1", skiprows=3, skipfooter=12, engine='python', decimal=",", thousands=".")

# %%
ordernados_por_total = dados_hospitalares_1.sort_values(by="Total", ascending=True)
ordernados_por_total.head()
# Out:
#   Unidade da Federação    2008/Jan    2008/Fev    2008/Mar    2008/Abr  \
# 5             16 Amapá  1120973.34  1268740.33   974651.24  1141137.32
# 3           14 Roraima   657889.53   777939.31   718688.03   839994.39
# 1              12 Acre   902416.00  1497206.26  1794028.48  1730469.42
# 6         17 Tocantins  3441592.69  4985688.85  6205612.60  4984482.09
# 0          11 Rondônia  1388528.39  2931283.42  1541682.52  1525314.96
#
#      2008/Mai    2008/Jun    2008/Jul    2008/Ago    2008/Set  ...  \
# 5   866346.18  1440978.95  1426659.48  1475551.38  1651341.43  ...
# 3   862347.96   832440.66   996693.09   894271.18   910424.17  ...
# 1  1819443.92  1828496.00  2511754.59  2089107.14  2275708.53  ...
# 6  5511002.46  4927934.22  5445602.28  5413710.38  5596669.50  ...
# 0  1645953.84  1406150.68  3065279.01  3231494.61  3117178.63  ...
#
#       2024/Mai     2024/Jun     2024/Jul     2024/Ago     2024/Set  \
# ...

# %%
mes_mais_recente = ["Unidade da Federação" , dados_hospitalares_1.columns[-2]]
mes_mais_recente
# Out:
# ['Unidade da Federação', '2025/Jan']

# %%
gastos_do_mais_recente = ordernados_por_total[mes_mais_recente]
gastos_do_mais_recente.head()
# Out:
#   Unidade da Federação     2025/Jan
# 5             16 Amapá   3830729.66
# 3           14 Roraima            -
# 1              12 Acre            -
# 6         17 Tocantins  10098888.54
# 0          11 Rondônia  11741428.22

# %%
gastos_do_mais_recente.dtypes
gastos_do_mais_recente = gastos_do_mais_recente

gastos_do_mais_recente['2025/Jan'] = gastos_do_mais_recente['2025/Jan'].replace(r'[^\d.-]', '', regex=True)

# Agora, convertemos a coluna para float
gastos_do_mais_recente['2025/Jan'] = pd.to_numeric(gastos_do_mais_recente['2025/Jan'], errors='coerce')

# Substituímos qualquer valor NaN por 0 ou outro valor (se necessário)
gastos_do_mais_recente['2025/Jan'] = gastos_do_mais_recente['2025/Jan'].fillna(0)

# Verifique se a conversão foi bem-sucedida
print(gastos_do_mais_recente[['Unidade da Federação', '2025/Jan']].head())
# Out:
#   Unidade da Federação     2025/Jan
# 5             16 Amapá   3830729.66
# 3           14 Roraima         0.00
# 1              12 Acre         0.00
# 6         17 Tocantins  10098888.54
# 0          11 Rondônia  11741428.22
# C:\Users\Lucas Lira\AppData\Local\Temp\ipykernel_4484\2700254448.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gastos_do_mais_recente['2025/Jan'] = gastos_do_mais_recente['2025/Jan'].replace(r'[^\d.-]', '', regex=True)
# C:\Users\Lucas Lira\AppData\Local\Temp\ipykernel_4484\2700254448.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
import matplotlib.pyplot as plt

gastos_do_mais_recente.plot(x = "Unidade da Federação", y = "2025/Jan", figsize=(12,9))
# Out:
# <Axes: xlabel='Unidade da Federação'>
