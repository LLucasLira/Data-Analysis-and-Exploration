# %% [markdown]
# # Visualização de dados

# %% [markdown]
# ## Aula 1 - Tratamento, exploração e visualização de dados

# %% [markdown]
# ## 1. Tratamento, exploração e visualização de dados

# %%
import pandas as pd

# %%
ibge_estimativa_git = pd.read_excel(r"https://github.com/alura-cursos/agendamento-hospitalar/blob/main/dados/estimativa_dou_2020.xls?raw=true")

# %%
ibge_estimativa_git.head()
# Out:
#   ESTIMATIVAS DA POPULAÇÃO RESIDENTE NO BRASIL E UNIDADES DA FEDERAÇÃO COM DATA DE REFERÊNCIA EM 1º DE JULHO DE 2020  \
# 0                     BRASIL E UNIDADES DA FEDERAÇÃO
# 1                                             Brasil
# 2                                       Região Norte
# 3                                           Rondônia
# 4                                               Acre
#
#    Unnamed: 1          Unnamed: 2
# 0         NaN  POPULAÇÃO ESTIMADA
# 1         NaN           211755692
# 2         NaN            18672591
# 3         NaN             1796460
# 4         NaN              894470

# %%
dados_da_populacao_io = """
Posição	Unidade federativa	População	% da pop. Total	País comparável
Habitantes
1	São Paulo	46 649 132	21,9%	Flag of Spain.svg Espanha (46 439 864)
2	Minas Gerais	21 411 923	10,1%	Sri Lanka (20 675 000)
3	Rio de Janeiro	17 463 349	8,2%	Países Baixos (16 922 900)
4	Bahia Bahia	14 985 284	7,1%	Chade (14 037 000)
5	Paraná	11 597 484	5,4%	Bolívia (11 410 651)
6	Rio Grande do Sul	11 466 630	5,4%	Bélgica (11 250 659)
7	Pernambuco	9 674 793	4,5%	Bielorrússia (9 485 300)
8	Ceará	9 240 580	4,3%	Emirados Árabes Unidos (9 157 000)
9	Pará	8 777 124	4,1%	Áustria (8 602 112)
10	Santa Catarina	7 338 473	3,4%	Sérvia (7 114 393)
11	Goiás	7 206 589	3,4%	Paraguai (7 003 406)
12	Maranhão	7 153 262	3,4%	Paraguai (7 003 406)
13	Amazonas	4 269 995	2,0%	Líbano (4 168 000)
14	Espírito Santo	4 108 508	1,9%	Líbano (4 168 000)
15	Paraíba	4 059 905	1,9%	Líbano (4 168 000)
16	Mato Grosso	3 567 234	1,7%	Uruguai (3 415 866)
17	Rio Grande do Norte	3 560 903	1,7%	Uruguai (3 415 866)
18	Alagoas	3 365 351	1,6%	Uruguai (3 415 866)
19	Piauí	3 289 290	1,6%	Kuwait (3 268 431)
20	Distrito Federal	3 094 325	1,4%	Lituânia (2 900 787)
21	Mato Grosso do Sul	2 839 188	1,3%	Jamaica (2 717 991)
22	Sergipe	2 338 474	1,1%	Namíbia (2 280 700)
23	Rondônia	1 815 278	0,8%	Gabão (1 725 000)
24	Tocantins	1 607 363	0,7%	Bahrein (1 359 800)
25	Acre	906 876	0,4%	Fiji (859 178)
26	Amapá	877 613	0,4%	Fiji (859 178)
27	Roraima	652 713	0,3%	Luxemburgo (562 958)"""

# %%
from io import StringIO  

dados_da_populacao_io = StringIO(dados_da_populacao_io)

dados_da_populacao_io = pd.read_csv(dados_da_populacao_io, sep = "\t")

dados_da_populacao_io
# Out:
#        Posição   Unidade federativa   População % da pop. Total  \
# 0   Habitantes                  NaN         NaN             NaN
# 1            1            São Paulo  46 649 132           21,9%
# 2            2         Minas Gerais  21 411 923           10,1%
# 3            3       Rio de Janeiro  17 463 349            8,2%
# 4            4          Bahia Bahia  14 985 284            7,1%
# 5            5               Paraná  11 597 484            5,4%
# 6            6    Rio Grande do Sul  11 466 630            5,4%
# 7            7           Pernambuco   9 674 793            4,5%
# 8            8                Ceará   9 240 580            4,3%
# 9            9                 Pará   8 777 124            4,1%
# 10          10       Santa Catarina   7 338 473            3,4%
# 11          11                Goiás   7 206 589            3,4%
# 12          12             Maranhão   7 153 262            3,4%
# 13          13             Amazonas   4 269 995            2,0%
# ...

# %% [markdown]
# ## Removendo valores nulos

# %%
dados_da_populacao_io = dados_da_populacao_io.dropna()

dados_da_populacao_io
# Out:
#    Posição   Unidade federativa   População % da pop. Total  \
# 1        1            São Paulo  46 649 132           21,9%
# 2        2         Minas Gerais  21 411 923           10,1%
# 3        3       Rio de Janeiro  17 463 349            8,2%
# 4        4          Bahia Bahia  14 985 284            7,1%
# 5        5               Paraná  11 597 484            5,4%
# 6        6    Rio Grande do Sul  11 466 630            5,4%
# 7        7           Pernambuco   9 674 793            4,5%
# 8        8                Ceará   9 240 580            4,3%
# 9        9                 Pará   8 777 124            4,1%
# 10      10       Santa Catarina   7 338 473            3,4%
# 11      11                Goiás   7 206 589            3,4%
# 12      12             Maranhão   7 153 262            3,4%
# 13      13             Amazonas   4 269 995            2,0%
# 14      14       Espírito Santo   4 108 508            1,9%
# 15      15              Paraíba   4 059 905            1,9%
# ...

# %% [markdown]
# ## Desafio: Limpar os dados do excel (Sem regiões) com nomes de colunas apropriados

# %%
ibge_estimativa_git = ibge_estimativa_git.drop(columns="Unnamed: 1").head()
ibge_estimativa_git.head()
# Out:
#   ESTIMATIVAS DA POPULAÇÃO RESIDENTE NO BRASIL E UNIDADES DA FEDERAÇÃO COM DATA DE REFERÊNCIA EM 1º DE JULHO DE 2020  \
# 0                     BRASIL E UNIDADES DA FEDERAÇÃO
# 1                                             Brasil
# 2                                       Região Norte
# 3                                           Rondônia
# 4                                               Acre
#
#            Unnamed: 2
# 0  POPULAÇÃO ESTIMADA
# 1           211755692
# 2            18672591
# 3             1796460
# 4              894470

# %% [markdown]
# ## 1ª Forma de renomear as colunas

# %%
ibge_estimativa_git = ibge_estimativa_git.rename(columns={"ESTIMATIVAS DA POPULAÇÃO RESIDENTE NO BRASIL E UNIDADES DA FEDERAÇÃO COM DATA DE REFERÊNCIA EM 1º DE JULHO DE 2020": "Unidade da Federação",
                                    "Unnamed: 2": "População Estimada"})
ibge_estimativa_git.head()
# Out:
#              Unidade da Federação  População Estimada
# 0  BRASIL E UNIDADES DA FEDERAÇÃO  POPULAÇÃO ESTIMADA
# 1                          Brasil           211755692
# 2                    Região Norte            18672591
# 3                        Rondônia             1796460
# 4                            Acre              894470

# %% [markdown]
# ## 2ª Fomra de renomear as colunas

# %%
ibge_estimativa_git = pd.read_excel(r"https://github.com/alura-cursos/agendamento-hospitalar/blob/main/dados/estimativa_dou_2020.xls?raw=true")
ibge_estimativa_git.head()
# Out:
#   ESTIMATIVAS DA POPULAÇÃO RESIDENTE NO BRASIL E UNIDADES DA FEDERAÇÃO COM DATA DE REFERÊNCIA EM 1º DE JULHO DE 2020  \
# 0                     BRASIL E UNIDADES DA FEDERAÇÃO
# 1                                             Brasil
# 2                                       Região Norte
# 3                                           Rondônia
# 4                                               Acre
#
#    Unnamed: 1          Unnamed: 2
# 0         NaN  POPULAÇÃO ESTIMADA
# 1         NaN           211755692
# 2         NaN            18672591
# 3         NaN             1796460
# 4         NaN              894470

# %%
ibge_estimativa_git.columns = ["uf", "populacao", "pais_comparavel" ]
ibge_estimativa_git.head()
# Out:
#                                uf  populacao     pais_comparavel
# 0  BRASIL E UNIDADES DA FEDERAÇÃO        NaN  POPULAÇÃO ESTIMADA
# 1                          Brasil        NaN           211755692
# 2                    Região Norte        NaN            18672591
# 3                        Rondônia        NaN             1796460
# 4                            Acre        NaN              894470

# %%
ibge_estimativa_git = ibge_estimativa_git.drop(index=0)
ibge_estimativa_git.head()
# Out:
#              uf  populacao pais_comparavel
# 1        Brasil        NaN       211755692
# 2  Região Norte        NaN        18672591
# 3      Rondônia        NaN         1796460
# 4          Acre        NaN          894470
# 5      Amazonas        NaN         4207714

# %%
ibge_estimativa_git = ibge_estimativa_git.drop(columns="populacao").head()
ibge_estimativa_git.head()
# Out:
#              uf pais_comparavel
# 1        Brasil       211755692
# 2  Região Norte        18672591
# 3      Rondônia         1796460
# 4          Acre          894470
# 5      Amazonas         4207714

# %% [markdown]
# ## Ler dados da Wikipedia com read_html

# %%
dados_wikipedia = pd.read_html("https://pt.wikipedia.org/wiki/Lista_de_unidades_federativas_do_Brasil_por_popula%C3%A7%C3%A3o#cite_note-IBGE_POP-1", skiprows=1)

# %%
dados_wikipedia
# Out:
# [     Unidade federativa  2024 (est.)         2022       %        Abs.  \
#                São Paulo   45 973 194   44 411 238   7,63%   3 149 039
#  0          Minas Gerais   21 322 691   20 539 989   4,81%     942 659
#  1        Rio de Janeiro   17 219 679   16 055 174   0,41%      65 245
#  2                 Bahia   14 850 513   14 141 626   0,89%     124 720
#  3                Paraná   11 824 665   11 444 380   9,57%     999 854
#  4     Rio Grande do Sul   11 229 915   10 882 965   1,77%     189 036
#  5            Pernambuco    9 539 029    9 058 931   2,98%     262 483
#  6                 Ceará    9 233 656    8 794 957   4,05%     342 576
#  7                  Pará    8 664 306    8 120 131   7,11%     539 080
#  8        Santa Catarina    8 058 441    7 610 361  21,80%   1 361 925
#  9                 Goiás    7 350 483    7 056 495  17,53%   1 052 707
#  10             Maranhão    7 010 960    6 776 699   3,07%     201 910
# ...

# %% [markdown]
# ## Ajustando espaços em branco

# %%
dados_da_populacao_io.columns = ["posicao", "uf", "populacao", "porcentagem", "pais_comparavel"]
dados_da_populacao_io.head()
# Out:
#   posicao              uf   populacao porcentagem  \
# 1       1       São Paulo  46 649 132       21,9%
# 2       2    Minas Gerais  21 411 923       10,1%
# 3       3  Rio de Janeiro  17 463 349        8,2%
# 4       4     Bahia Bahia  14 985 284        7,1%
# 5       5          Paraná  11 597 484        5,4%
#
#                           pais_comparavel
# 1  Flag of Spain.svg Espanha (46 439 864)
# 2                  Sri Lanka (20 675 000)
# 3              Países Baixos (16 922 900)
# 4                      Chade (14 037 000)
# 5                    Bolívia (11 410 651)

# %%
dados_da_populacao_io["populacao"] = dados_da_populacao_io["populacao"].str.replace(' ', '').astype(int)
dados_da_populacao_io.head()
# Out:
# C:\Users\Lucas Lira\AppData\Local\Temp\ipykernel_13016\2816833581.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dados_da_populacao_io["populacao"] = dados_da_populacao_io["populacao"].str.replace(' ', '').astype(int)
#   posicao              uf  populacao porcentagem  \
# 1       1       São Paulo   46649132       21,9%
# 2       2    Minas Gerais   21411923       10,1%
# 3       3  Rio de Janeiro   17463349        8,2%
# 4       4     Bahia Bahia   14985284        7,1%
# 5       5          Paraná   11597484        5,4%
#
#                           pais_comparavel
# 1  Flag of Spain.svg Espanha (46 439 864)
# 2                  Sri Lanka (20 675 000)
# 3              Países Baixos (16 922 900)
# ...

# %% [markdown]
# ## Verificando tipagem de cada coluna

# %%
dados_da_populacao_io.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 27 entries, 1 to 27
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   posicao          27 non-null     object
#  1   uf               27 non-null     object
#  2   populacao        27 non-null     int64
#  3   porcentagem      27 non-null     object
#  4   pais_comparavel  27 non-null     object
# dtypes: int64(1), object(4)
# memory usage: 1.3+ KB

# %% [markdown]
# ## 2. Proporcionalidade e Seaborn
